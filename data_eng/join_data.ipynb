# %% [markdown]
# # Intro
#
# In this notebook we will be joining the features in a 300 km radius for DC data and then also joining on the other datasets while we are at it. The goal is to make a dataset of stations with applicable data for their surrounding environment.

# %%
from google.colab import drive
drive.mount('/content/drive')
import os, shutil, subprocess

WORK_DIR = '/content/drive/MyDrive/DL_Project'
os.chdir(WORK_DIR)
print('cwd:', os.getcwd())
# Out:
# Mounted at /content/drive
# cwd: /content/drive/MyDrive/DL_Project

# %%
import pandas as pd
import geopandas as gpd

# %% [markdown]
# # Import
#
# First we gotta import the data. Lets first do our station dataset and then get the shape file.

# %%
# read in cabi data
cabi = pd.read_parquet('data/cabi_combined_data.parquet')

# %%
built_env = gpd.read_file("data/built_environment_indicators/Data_Hacktoberfest_Built_Environment_Final_Data.shp")
print(built_env.crs)
print(built_env.head())
print(built_env.columns.tolist())
# Out:
# EPSG:26985
#   TRACTCE        GEOID  m1_1_schoo  m1_2_quali  m1_3_playg  m1_4_cross  \
# 0  009807  11001009807    0.999899    0.000000    0.515735    0.152876
# 1  009802  11001009802    0.999901    0.000000    0.999901    0.261362
# 2  009803  11001009803    0.999894    0.000000    0.171991    0.088983
# 3  002002  11001002002    0.999899    0.999899    0.999869    0.105417
# 4  002101  11001002101    0.999901    0.999766    0.895557    0.222397
#
#    m1_5_safe_  m1_6_libra  m1_7_wirel  m1_8_broad  ...    d1_raw    d2_raw  \
# 0    0.000000    0.813928    0.999899    0.645201  ...  0.372166  0.019417
# 1    0.000000    0.648101    0.999901    0.683710  ...  0.530679  0.014563
# 2    0.699218    0.927700    0.999894    0.772940  ...  0.389224  0.184466
# 3    0.397312    0.546744    0.999899    0.889110  ...  0.561015  0.213592
# 4    0.999901    0.278853    0.999901    0.831951  ...  0.684580  0.092233
#
#      d3_raw    d4_raw    d5_raw    d6_raw    d7_raw    d8_raw    d9_raw  \
# 0  0.434466  0.592281  0.526896  0.321904  0.324029  0.422330  0.388252
# 1  0.458738  0.486353  0.329745  0.498068  0.736650  0.515777  0.426942
# 2  0.410194  0.570329  0.375728  0.409719  0.388350  0.497087  0.393932
# 3  0.419903  0.330573  0.504068  0.519549  0.519417  0.491262  0.519709
# 4  0.466019  0.399867  0.388066  0.672340  0.779126  0.392718  0.620146
#
#                                             geometry
# 0  POLYGON ((398491.738 128457.346, 398491.834 12...
# 1  POLYGON ((399950.421 129241.354, 399950.421 12...
# 2  POLYGON ((399269.719 129539.662, 399275.451 12...
# 3  POLYGON ((396843.078 142427.273, 396843.373 14...
# 4  POLYGON ((397552.349 143358.167, 397552.528 14...
#
# [5 rows x 105 columns]
# ['TRACTCE', 'GEOID', 'm1_1_schoo', 'm1_2_quali', 'm1_3_playg', 'm1_4_cross', 'm1_5_safe_', 'm1_6_libra', 'm1_7_wirel', 'm1_8_broad', 'm1_9_recre', 'm2_1_commu', 'm3_1_banks', 'm3_2_check', 'm4_1_quali', 'm4_2_share', 'm4_3_affor', 'm4_4_vacan', 'm5_1_buses', 'm5_2_metro', 'm5_3_capit', 'm5_4_bike_', 'm5_5_sidew', 'm5_6_parki', 'm6_1_groce', 'm6_2_low_f', 'm6_3_farme', 'm6_4_healt', 'm6_5_resta', 'm6_6_liquo', 'm7_1_healt', 'm7_2_menta', 'm8_1_urban', 'm8_2_parks', 'm8_3_trail', 'm8_4_land_', 'm8_5_posit', 'm8_6_flood', 'm9_1_vacan', 'm9_2_stree', 'm9_3_polic', 'm9_4_fire_', 'm9_5_HIN', 'm1_1_sch_1', 'm1_2_qua_1', 'm1_3_pla_1', 'm1_4_cro_1', 'm1_5_safe1', 'm1_6_lib_1', 'm1_7_wir_1', 'm1_8_bro_1', 'm1_9_rec_1', 'm2_1_com_1', 'm3_1_ban_1', 'm3_2_che_1', 'm4_1_qua_1', 'm4_2_sha_1', 'm4_3_aff_1', 'm4_4_vac_1', 'm5_1_bus_1', 'm5_2_met_1', 'm5_3_cap_1', 'm5_4_bike1', 'm5_5_sid_1', 'm5_6_par_1', 'm6_1_gro_1', 'm6_2_low_1', 'm6_3_far_1', 'm6_4_hea_1', 'm6_5_res_1', 'm6_6_liq_1', 'm7_1_hea_1', 'm7_2_men_1', 'm8_1_urb_1', 'm8_2_par_1', 'm8_3_tra_1', 'm8_4_land1', 'm8_5_pos_1', 'm8_6_flo_1', 'm9_1_vac_1', 'm9_2_str_1', 'm9_3_pol_1', 'm9_4_fire1', 'm9_5_HIN_s', 'd1_scale', 'd2_scale', 'd3_scale', 'd4_scale', 'd5_scale', 'd6_scale', 'd7_scale', 'd8_scale', 'd9_scale', 'doverall_s', 'priority', 'd1_raw', 'd2_raw', 'd3_raw', 'd4_raw', 'd5_raw', 'd6_raw', 'd7_raw', 'd8_raw', 'd9_raw', 'geometry']

# %% [markdown]
# # Filter Cabi
# Now lets filter the capital bikeshare dataset down to what it needs to be. We specifically just want information on all stations

# %%
print(cabi.columns)
# stations can have mutliple rows, we really just want one lon / lat for each station. I just take the first
stations = cabi[['start_station_id', 'start_station_name', 'start_lat', 'start_lng']].groupby('start_station_id').head(1).copy()
# now lets rename
stations.rename(columns ={'start_station_id' : 'station_id', 
                            'start_station_name' : 'station_name',
                            'start_lat' : "latitude",
                            "start_lng" : 'longitude'}, inplace=True)
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', '_source_zip', '_source_file'],
#       dtype='object')

# %%
# just double checking things here
print(stations.columns)
print(stations.head(5))
print(stations.shape)
print(stations.station_id.nunique())
# Out:
# Index(['station_id', 'station_name', 'latitude', 'longitude'], dtype='object')
#    station_id                                       station_name   latitude  \
# 0     31087.0                            Monroe Ave & Leslie Ave  38.820932
# 1     31283.0                                     14th & L St NW  38.903658
# 3     31518.0                        New York Ave & Hecht Ave NE  38.915604
# 4     32608.0  Falls Church City Hall / Park Ave & Little Fal...  38.885434
# 6     31104.0                        Adams Mill & Columbia Rd NW  38.922925
#
#    longitude
# 0 -77.053096
# 1 -77.031737
# 3 -76.983683
# 4 -77.173605
# 6 -77.042581
# (862, 4)
# 862

# %% [markdown]
# # Join data

# %%
# convert stations to a geopandas dataframe

stations_gpd = gpd.GeoDataFrame(
    stations,
    geometry=gpd.points_from_xy(stations.longitude, stations.latitude),
    crs="EPSG:4326"  
).to_crs("EPSG:26985")

# %%
stations_joined = gpd.sjoin(stations_gpd, built_env, how="left", predicate="within")

# %%
# lets count and check

stations_joined.groupby('station_id')['m1_1_schoo'].sum().reset_index()
# Out:
#      station_id  m1_1_schoo
# 0       22907.0    0.817486
# 1       30200.0    0.999894
# 2       30201.0    0.999894
# 3       31000.0    0.000000
# 4       31001.0    0.000000
# ..          ...         ...
# 857     33201.0    0.999900
# 858     33202.0    0.999899
# 859     33203.0    0.991277
# 860     33204.0    0.999894
# 861    322840.0    0.000000
#
# [862 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 10))

built_env.plot(ax=ax, color="lightblue", edgecolor="gray", alpha=0.5, label="Built Env")
stations_gpd.plot(ax=ax, color="red", markersize=5, label="Stations")

plt.legend()
plt.title("Built Environment vs Stations")
plt.show()
# Out:
# /tmp/ipykernel_9750/2488103942.py:8: UserWarning: Legend does not support handles for PatchCollection instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   plt.legend()

# %%
# convert back to a normal pandas
stations_built_env = stations_joined.drop(columns="geometry").reset_index(drop=True)
print(stations_built_env.head(10))
print(stations_built_env.shape)
# Out:
#    station_id                                       station_name   latitude  \
# 0     31087.0                            Monroe Ave & Leslie Ave  38.820932
# 1     31283.0                                     14th & L St NW  38.903658
# 2     31518.0                        New York Ave & Hecht Ave NE  38.915604
# 3     32608.0  Falls Church City Hall / Park Ave & Little Fal...  38.885434
# 4     31104.0                        Adams Mill & Columbia Rd NW  38.922925
# 5     31105.0                               14th & Harvard St NW  38.926800
# 6     31606.0                      Potomac & Pennsylvania Ave SE  38.880300
# 7     31607.0                                     13th & E St SE  38.882921
# 8     31641.0                      2nd St & Massachusetts Ave NE  38.894972
# 9     31310.0                      Connecticut & Nebraska Ave NW  38.955075
#
#    longitude  index_right TRACTCE        GEOID  m1_1_schoo  m1_2_quali  \
# 0 -77.053096          NaN     NaN          NaN         NaN         NaN
# 1 -77.031737        141.0  010100  11001010100    0.999902    0.619431
# 2 -76.983683        107.0  008803  11001008803    0.999902    0.307632
# 3 -77.173605          NaN     NaN          NaN         NaN         NaN
# 4 -77.042581         71.0  003901  11001003901    0.999905    0.000000
# 5 -77.032200        116.0  003000  11001003000    0.999908    0.999908
# 6 -76.986200        200.0  007100  11001007100    0.999900    0.128034
# 7 -76.987862        201.0  006900  11001006900    0.999902    0.961083
# 8 -77.003135         97.0  008200  11001008200    0.999898    0.999898
# 9 -77.070026        180.0  001100  11001001100    0.999903    0.000000
#
#    m1_3_playg  ...  priority    d1_raw    d2_raw    d3_raw    d4_raw  \
# 0         NaN  ...       NaN       NaN       NaN       NaN       NaN
# 1    0.118688  ...       0.0  0.620595  0.800971  0.480583  0.695103
# 2    0.160133  ...       0.0  0.498469  0.461165  0.483010  0.698327
# 3         NaN  ...       NaN       NaN       NaN       NaN       NaN
# 4    0.999905  ...       0.0  0.823105  0.669903  0.500000  0.365470
# 5    0.842139  ...       0.0  0.903498  0.665049  0.502427  0.591067
# 6    0.849190  ...       0.0  0.545645  0.805825  0.616505  0.588200
# 7    0.999902  ...       0.0  0.744175  0.781553  0.483010  0.545605
# 8    0.457232  ...       0.0  0.546598  0.509709  0.415049  0.364024
# 9    0.454381  ...       0.0  0.665266  0.737864  0.483010  0.668868
#
#      d5_raw    d6_raw    d7_raw    d8_raw    d9_raw
# 0       NaN       NaN       NaN       NaN       NaN
# 1  0.732126  0.593335  0.815534  0.410194  0.640194
# 2  0.356825  0.535932  0.706311  0.480097  0.274612
# 3       NaN       NaN       NaN       NaN       NaN
# 4  0.773199  0.846126  0.922330  0.653398  0.880437
# 5  0.794170  0.878650  0.983010  0.550000  0.714660
# 6  0.364019  0.465423  0.452670  0.472816  0.427913
# 7  0.567587  0.691879  0.824029  0.587379  0.689612
# 8  0.608665  0.501224  0.591019  0.506311  0.674951
# 9  0.565592  0.342971  0.283981  0.588350  0.398835
#
# [10 rows x 109 columns]
# (862, 109)

# %%
stations_built_env.to_parquet("data/stations_with_buil_env.parquet", index=False, engine="pyarrow", compression="snappy")

# %% [markdown]
# # Join Census Information
# This will be another overlap join if we can get it

# %%
# read in data
census = gpd.read_file("data/census_tract_demographics.gpkg")
census = census.to_crs("EPSG:26985")

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 10))

census.plot(ax=ax, color="lightblue", edgecolor="gray", alpha=0.5, label="Built Env")
stations_gpd.plot(ax=ax, color="red", markersize=5, label="Stations")

plt.legend()
plt.title("Census data vs Stations")
plt.show()
# Out:
# /tmp/ipykernel_9750/1768852046.py:8: UserWarning: Legend does not support handles for PatchCollection instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   plt.legend()

# %%
# lets now join it
stations_joined = stations_joined.drop(columns="index_right")
stations_with_census = gpd.sjoin(stations_joined, census, how="left", predicate="within")

# %%
stations_with_census
# Out:
#           station_id                                       station_name  \
# 0            31087.0                            Monroe Ave & Leslie Ave
# 1            31283.0                                     14th & L St NW
# 3            31518.0                        New York Ave & Hecht Ave NE
# 4            32608.0  Falls Church City Hall / Park Ave & Little Fal...
# 6            31104.0                        Adams Mill & Columbia Rd NW
# ...              ...                                                ...
# 20122679     33202.0                            27th St & Woodley Rd NW
# 20135184     33201.0                           Kansas Ave & Blair Rd NW
# 20148509     33203.0                       Howard Rd & Suitland Pkwy SE
# 20447484     33204.0                                15th & Chapin St NW
# 20841628     22907.0                                          3035 V St
#
#            latitude  longitude                       geometry TRACTCE_left  \
# 0         38.820932 -77.053096   POINT (395389.143 128129.52)          NaN
# 1         38.903658 -77.031737  POINT (397247.151 137311.847)       010100
# 3         38.915604 -76.983683   POINT (401415.09 138637.599)       008803
# 4         38.885434 -77.173605  POINT (384937.765 135302.683)          NaN
# 6         38.922925 -77.042581  POINT (396307.547 139451.027)       003901
# ...             ...        ...                            ...          ...
# 20122679  38.925764 -77.055113  POINT (395221.012 139766.761)       000501
# 20135184  38.962406 -77.010476  POINT (399092.067 143833.004)       009505
# 20148509  38.865149 -77.001045  POINT (399909.308 133036.573)       007401
# 20447484  38.921468 -77.035244  POINT (396943.719 139289.016)       003701
# 20841628  38.918767 -76.965328  POINT (403006.792 138989.163)       011100
#
#            GEOID_left  m1_1_schoo  m1_2_quali  m1_3_playg  ...  pop_maleE  \
# 0                 NaN         NaN         NaN         NaN  ...     1870.0
# 1         11001010100    0.999902    0.619431    0.118688  ...     1203.0
# 3         11001008803    0.999902    0.307632    0.160133  ...     2362.0
# 4                 NaN         NaN         NaN         NaN  ...     1926.0
# 6         11001003901    0.999905    0.000000    0.999905  ...     1137.0
# ...               ...         ...         ...         ...  ...        ...
# 20122679  11001000501    0.999899    0.130074    0.141519  ...     1574.0
# 20135184  11001009505    0.999900    0.151707    0.846429  ...     1730.0
# 20148509  11001007401    0.991277    0.000000    0.481516  ...      344.0
# 20447484  11001003701    0.999894    0.000000    0.999894  ...     1282.0
# 20841628  11001011100    0.817486    0.000000    0.360518  ...     2653.0
#
#           pop_maleM  pop_femaleE  pop_femaleM  median_ageE  median_ageM  \
# 0             234.0       1881.0        193.0         35.8          1.0
# 1             258.0       1388.0        288.0         34.5          0.7
# 3             376.0       2720.0        379.0         32.3          2.7
# 4             231.0       1733.0        190.0         41.6          4.9
# 6             201.0       1597.0        503.0         34.5          5.4
# ...             ...          ...          ...          ...          ...
# 20122679      349.0       2036.0        419.0         38.5          4.1
# 20135184      358.0       2763.0        494.0         33.8          4.0
# 20148509      118.0        905.0        342.0         38.9         13.7
# 20447484      170.0       1226.0        189.0         34.8          1.5
# 20841628      542.0       2375.0        374.0         41.9          3.0
#
#           median_hh_incomeE  median_hh_incomeM    year  state
# 0                  199444.0            32558.0  2024.0     VA
# 1                  112670.0            38301.0  2024.0     DC
# 3                  102585.0            20931.0  2024.0     DC
# 4                  204183.0            26759.0  2024.0     VA
# 6                  134922.0            57867.0  2024.0     DC
# ...                     ...                ...     ...    ...
# 20122679           110774.0            16937.0  2024.0     DC
# 20135184            95078.0            31875.0  2024.0     DC
# 20148509            31862.0            14511.0  2024.0     DC
# 20447484           134508.0            22367.0  2024.0     DC
# 20841628            80536.0            48056.0  2024.0     DC
#
# [862 rows x 136 columns]

# %% [markdown]
# # Write out

# %%
stations_finished = stations_with_census.drop(columns="geometry").reset_index(drop=True)
stations_finished.to_parquet("data/stations_finished.parquet", index=False, engine="pyarrow", compression="snappy")
